# %% [markdown]
# <a href="https://colab.research.google.com/github/rush181200/newsInsta/blob/main/newsInsta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install newsapi-python
# !pip install pillow
# !pip install Bot
# !pip install instagrapi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: newsapi-python in /usr/local/lib/python3.10/dist-packages (0.2.7)
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.10/dist-packages (from newsapi-python) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0->newsapi-python) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0->newsapi-python) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0->newsapi-python) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0->newsapi-python) (2.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (8.4.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement Bot (from versions: none)
# ERROR: No matching distribution found for Bot

# %%
from newsapi import NewsApiClient
apiKey="2db2450da98f40068bd2aca51978f063"

newsapi = NewsApiClient(api_key='2db2450da98f40068bd2aca51978f063')

# sources = newsapi.get_sources(country='us',language='en')
# sources

# %%
import pandas as pd
import json
import requests

url = "https://newsapi.org/v2/top-headlines?country=us&apiKey=2db2450da98f40068bd2aca51978f063"

response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Extract the JSON data from the response
    data = response.json()

    # Process the data as needed
    print(data)
else:
    # Print an error message if the request was not successful
    print("Error:", response.status_code)

df = pd.json_normalize(data['articles'])
df
# Out:
# {'status': 'ok', 'totalResults': 35, 'articles': [{'source': {'id': 'cnn', 'name': 'CNN'}, 'author': 'Simone McCarthy', 'title': 'Ukraine’s Zelensky and India’s Modi hold first face-to-face since Russian invasion - CNN', 'description': 'Ukrainian President Volodymyr Zelensky met with Indian Prime Minister Narendra Modi on the sidelines of the Group of Seven (G7) summit in Japan Saturday, the first in-person meeting between the two since Russia’s invasion began.', 'url': 'https://www.cnn.com/2023/05/20/asia/zelensky-modi-meet-g7-japan-hiroshima-intl-hnk/index.html', 'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230520090121-03-zelensky-hiroshima-g7.jpg?c=16x9&q=w_800,c_fill', 'publishedAt': '2023-05-21T00:22:00Z', 'content': 'Ukrainian President Volodymyr Zelensky met with Indian Prime Minister Narendra Modi on the sidelines of the Group of Seven (G7) summit in Japan Saturday, the first in-person meeting between the two s… [+3642 chars]'}, {'source': {'id': None, 'name': 'Page Six'}, 'author': 'Tamantha Ryan', 'title': "Priscilla Presley attends granddaughters' graduation, Riley is noticeably absent - Page Six", 'description': 'The former wife of Elvis Presley walked separately from the twins and their father, Michael Lockwood, on Saturday after leaving the commencement.', 'url': 'https://pagesix.com/2023/05/20/priscilla-presley-attends-granddaughters-graduation-riley-keough-absent/', 'urlToImage': 'https://pagesix.com/wp-content/uploads/sites/3/2023/05/NYPICHPDPICT000011449985.jpg?quality=75&strip=all&w=1200', 'publishedAt': '2023-05-20T23:53:00Z', 'content': 'Priscilla Presley was seen attending the graduation of her twin granddaughters, Harper and Finley but their big sister, Riley Keough, was noticeably absent from their big day.\r\nThe former wife of Elv… [+3513 chars]'}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Dan Agnew', 'title': "PGA Championship: Brooks Koepka's resurgence, an underdog story and more storylines from Round 3 - Yahoo Sports", 'description': 'Brooks Koepka is leading another major entering the final round. Can he finish Sunday with the title this time?', 'url': 'https://sports.yahoo.com/pga-championship-brooks-koepkas-resurgence-an-underdog-story-and-more-storylines-from-round-3-232628253.html', 'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/t5wmmPu.1lxDX5XPKeoI6g--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD03Mzk-/https://s.yimg.com/os/creatr-uploaded-images/2023-05/a65411a0-f75d-11ed-8fb7-ea6c91f6d77c', 'publishedAt': '2023-05-20T23:26:28Z', 'content': 'Brooks Koepka has put himself in position to win his third PGA Championship title with a strong third round at Oak Hill Country Club in Rochester, New York. (David Cannon/Getty Images)\r\nMajor champio… [+5249 chars]'}, {'source': {'id': None, 'name': 'CBS Sports'}, 'author': None, 'title': 'Lakers vs. Nuggets prediction, odds: 2023 NBA Western Conference finals picks, Game 3 bets by proven model - CBS Sports', 'description': "SportsLine's model simulated Game 3 of the Denver Nuggets vs. Los Angeles Lakers Western Conference finals in the 2023 NBA playoffs", 'url': 'https://www.cbssports.com/nba/news/lakers-vs-nuggets-prediction-odds-2023-nba-western-conference-finals-picks-game-3-bets-by-proven-model/', 'urlToImage': 'https://sportshub.cbsistatic.com/i/r/2023/05/20/2c8c413a-4920-429e-9017-e732255ee46e/thumbnail/1200x675/057d6d6554f89077cae89062ee6eef5a/lebron-james-los-angeles-lakers-usatsi.jpg', 'publishedAt': '2023-05-20T23:00:27Z', 'content': 'Game 3 of the 2023 NBA Western Conference Finals takes place at Crypto.com Arena on Saturday evening. The Los Angeles Lakers face an urgent situation, down 2-0 in the series to the\xa0Denver Nuggets. Th… [+4471 chars]'}, {'source': {'id': None, 'name': 'POLITICO.eu'}, 'author': 'Jones Hayden', 'title': "Russia's Wagner group claims control of Bakhmut, but Kyiv says fighting continues - POLITICO Europe", 'description': 'Heavy fighting was continuing in the city, Ukrainian De ...
#                                                author  \
# 0                                     Simone McCarthy
# 1                                       Tamantha Ryan
# 2                                           Dan Agnew
# 3                                                None
# 4                                        Jones Hayden
# 5                             Guardian staff reporter
# 6                                          Jake Coyle
# 7                                                None
# 8                        Justin McCurry, Rowena Mason
# 9                                                None
# 10                                     Maureen Mackey
# 11                                               None
# 12                                         Jared Gans
# 13                                               None
# 14                                    Matthew Sedacca
# 15  Rachel Roubein, Caroline Kitchener, Colby Itko...
# 16                                        Rob Landers
# 17                                     Hannah Furfaro
# 18                                     Rahul Malhotra
# 19                                        Kyle Morris
#
#                                                 title  \
# 0   Ukraine’s Zelensky and India’s Modi hold first...
# 1   Priscilla Presley attends granddaughters' grad...
# 2   PGA Championship: Brooks Koepka's resurgence, ...
# 3   Lakers vs. Nuggets prediction, odds: 2023 NBA ...
# 4   Russia's Wagner group claims control of Bakhmu...
# 5   Sudan's warring factions sign agreement for se...
# 6   Scorsese debuts 'Killers of the Flower Moon' i...
# 7   Join the Hunt: Astronomers Need Help Finding A...
# 8   Zelenskiy's G7 visit sends 'incredibly powerfu...
# 9   Renowned British novelist Martin Amis dies age...
# 10  Are you a mosquito magnet? It might be for one...
# 11  Florida's DeSantis seeks to disqualify judge i...
# 12  Russia puts ICC prosecutor on wanted list foll...
# 13  Tears of the Kingdom News Roundup, Interest in...
# 14  Sending F-16s to Ukraine carries 'enormous ris...
# 15  Republicans deploy new playbook for abortion b...
# 16  SpaceX Axiom-2 launch, Thunder on the Beach: B...
# 17  King County health officials investigating mea...
# 18  'Fast X' Leaves 'Guardians of the Galaxy Vol. ...
# 19  Nebraska senator flips out debating ban on sex...
#
#                                           description  \
# 0   Ukrainian President Volodymyr Zelensky met wit...
# 1   The former wife of Elvis Presley walked separa...
# 2   Brooks Koepka is leading another major enterin...
# 3   SportsLine's model simulated Game 3 of the Den...
# 4   Heavy fighting was continuing in the city, Ukr...
# 5   US and Saudi Arabia announce deal that comes a...
# 6   CANNES, France (AP) — Martin Scorsese unveiled...
# 7   Anyone with an internet connection can now joi...
# 8   The UK PM said the Ukrainian president attendi...
# 9   The author died of oesophageal cancer on Frida...
# 10  A new study by a team at Johns Hopkins Univers...
# 19  https://static.foxnews.com/foxnews.com/content...  2023-05-20T15:37:28Z
#
#                                               content            source.id  \
# 0   Ukrainian President Volodymyr Zelensky met wit...                  cnn
# 1   Priscilla Presley was seen attending the gradu...                 None
# 2   Brooks Koepka has put himself in position to w...                 None
# 3   Game 3 of the 2023 NBA Western Conference Fina...                 None
# 4   Russias Wagner paramilitary group claimed on S...                 None
# 5   Sudans warring factions signed an agreement la...                 None
# 6   CANNES, France (AP) Martin Scorsese unveiled K...     associated-press
# 7   ByKylianne Chadwick, University of ArizonaMay ...                 None
# 8   Rishi Sunak said Volodymyr Zelenskiys appearan...                 None
# 9                                                None                 None
# 10  New research has found that smelly armpits may...             fox-news
# 11  WASHINGTON, May 20 (Reuters) - Lawyers for Flo...              reuters
# 12  Skip to content\r\nRussia has placed the prose...             the-hill
# 13                                               None                 None
# 14  America and Western allies’ plans to send F-16...                 None
# 15  Comment on this story\r\nComment\r\nNebraska a...  the-washington-post
# 16  Cocoa Beach Mayor Ben Malik has a prediction f...                 None
# 17  A King County child has been diagnosed with me...                 None
# 18  Fast X, the 10th installment in the long-runni...                 None
# 19  A Friday morning session in the unicameral Neb...             fox-news
#
#             source.name
# 0                   CNN
# 1              Page Six
# 2   Yahoo Entertainment
# 3            CBS Sports
# 4           POLITICO.eu
# 5          The Guardian
# 6      Associated Press
# 7          SciTechDaily
# 8          The Guardian
# 9               YouTube
# 10             Fox News
# 11              Reuters
# 12             The Hill
# 13              YouTube
# 14        New York Post
# 15  The Washington Post
# 16        Florida Today
# 17    The Seattle Times
# 18         Collider.com
# 19             Fox News

# %%
print(data["articles"][0]['urlToImage'])
# Out:
# https://media.cnn.com/api/v1/images/stellar/prod/230520090121-03-zelensky-hiroshima-g7.jpg?c=16x9&q=w_800,c_fill

# %% [markdown]
# Get Image From News Api To Add news Topic on it

# %%
from PIL import Image,ImageDraw,ImageFont
from io import BytesIO
import textwrap



url = data["articles"][2]['urlToImage']

# Send a GET request to retrieve the image
response = requests.get(url)

image = Image.open(BytesIO(response.content))

new_width = 600
new_height = 900

# Resize the image
resized_image = image.resize((new_width, new_height))
d = ImageDraw.Draw(resized_image)
font = ImageFont.truetype("Roboto-Bold.ttf", 36)

# Set the text
text = data["articles"][2]['title'] 

# Set the text color
text_color = (0, 255, 255)  # White

# Set the maximum width for each line
max_width = 20

# Wrap the text into multiple lines
wrapped_text = textwrap.wrap(text, width=max_width)

# Calculate the total height required for the text
total_height = sum(font.getsize(line)[1] for line in wrapped_text)

# Calculate the starting position to center the text vertically
position_y = (resized_image.height - total_height) // 2

# Draw each line of text onto the image
for line in wrapped_text:
    line_width, line_height = font.getsize(line)
    position_x = (resized_image.width - line_width) // 2
    d.text((position_x, position_y), line, font=font, fill=text_color)
    position_y += line_height


# # Load the font
# font = ImageFont.truetype("Roboto-Bold.ttf", 45)
# d.text ((60, 60), data["articles"][0]['title'], font=font, fill= (255, 255, 255))


resized_image.save("todaynews.jpg")

# %%
from instagrapi import Client

# %%
from instagrapi.types import Usertag,Location

# %%
cl = Client()

# %%
cl.login("gettopnews","")
# Out:
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'i.instagram.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'i.instagram.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'i.instagram.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'i.instagram.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'i.instagram.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# True

# %%
media = cl.photo_upload(caption=data["articles"][2]['description'], path = "todaynews.jpg")
# Out:
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'i.instagram.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'i.instagram.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'i.instagram.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
